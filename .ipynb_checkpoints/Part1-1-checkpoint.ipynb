# %%
import stemgraphic
import pandas as pd

# %%
#Data 불러오기
data = pd.read_csv("/Users/jch/Documents/github/Study/Statistics_for_Archaeologists/Part1-1.csv")
data
# Out:
#       Name Site Stone type  Length(mm)
# 0   PR-001   PR      Chert        25.8
# 1   PR-002   PR      Chert         6.3
# 2   PR-003   PR      Flint        44.6
# 3   PR-004   PR      Chert        21.3
# 4   PR-005   PR      Flint        25.7
# 5   PR-006   PR      Chert        20.6
# 6   PR-007   PR      Chert        22.2
# 7   PR-008   PR      Chert        10.5
# 8   PR-009   PR      Chert        18.9
# 9   PR-010   PR      Chert        25.9
# 10  PR-011   PR      Chert        23.8
# 11  PR-012   PR      Chert        22.0
# 12  PR-013   PR      Chert        10.6
# 13  PR-014   PR      Flint        33.2
# 14  PR-015   PR      Chert        16.8
# 15  PR-016   PR      Chert        21.8
# 16  PR-017   PR      Flint        48.3
# 17  WF-001   WF      Chert        15.8
# 18  WF-002   WF      Flint        39.4
# 19  WF-003   WF      Flint        43.5
# 20  WF-004   WF      Flint        39.8
# 21  WF-005   WF      Chert        16.3
# 22  WF-006   WF      Flint        40.5
# 23  WF-007   WF      Flint        91.7
# 24  WF-008   WF      Chert        21.7
# 25  WF-009   WF      Chert        17.9
# 26  WF-010   WF      Flint        29.3
# 27  WF-011   WF      Flint        39.1
# 28  WF-012   WF      Flint        42.5
# 29  WF-013   WF      Flint        49.6
# 30  WF-014   WF      Chert        13.7
# 31  WF-015   WF      Chert        19.1
# 32  WF-016   WF      Flint        40.6
# 33  WF-017   WF      Flint        49.1
# 34  WF-018   WF      Flint        41.7
# 35  WF-019   WF      Chert        15.2
# 36  WF-020   WF      Chert        21.2
# 37  WF-021   WF      Flint        30.2
# 38  WF-022   WF      Flint        40.0
# 39  WF-023   WF      Chert        20.2
# 40  WF-024   WF      Flint        31.9
# 41  WF-025   WF      Flint        42.3
# 42  WF-026   WF      Flint        47.2
# 43  WF-027   WF      Flint        50.5
# 44  WF-028   WF      Chert        10.6
# 45  WF-029   WF      Chert        23.1
# 46  WF-030   WF      Flint        44.1
# 47  WF-031   WF      Flint        45.8

# %%
is_data_chert = data['Stone type'] == 'Chert'
data_chert = data[is_data_chert]

is_data_flint = data['Stone type'] == 'Flint'
data_flint = data[is_data_flint]

is_data_pr = data['Site'] == 'PR'
data_PR = data[is_data_pr]

is_data_wf = data['Site'] == "WF"
data_WF = data[is_data_wf]

data_PR
# Out:
#       Name Site Stone type  Length(mm)
# 0   PR-001   PR      Chert        25.8
# 1   PR-002   PR      Chert         6.3
# 2   PR-003   PR      Flint        44.6
# 3   PR-004   PR      Chert        21.3
# 4   PR-005   PR      Flint        25.7
# 5   PR-006   PR      Chert        20.6
# 6   PR-007   PR      Chert        22.2
# 7   PR-008   PR      Chert        10.5
# 8   PR-009   PR      Chert        18.9
# 9   PR-010   PR      Chert        25.9
# 10  PR-011   PR      Chert        23.8
# 11  PR-012   PR      Chert        22.0
# 12  PR-013   PR      Chert        10.6
# 13  PR-014   PR      Flint        33.2
# 14  PR-015   PR      Chert        16.8
# 15  PR-016   PR      Chert        21.8
# 16  PR-017   PR      Flint        48.3

# %%
#연습문제1
stemgraphic.stem_graphic(data["Length(mm)"], scale = 1)
stemgraphic.stem_graphic(data["Length(mm)"], scale = 5)
stemgraphic.stem_graphic(data["Length(mm)"], scale = 10)
# Out:
# (<Figure size 540x234 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0x12c838ac0>)

# %%
#연습문제2
stemgraphic.stem_graphic(data_chert["Length(mm)"], df2 = data_flint["Length(mm)"], scale = 1)
stemgraphic.stem_graphic(data_chert["Length(mm)"], df2 = data_flint["Length(mm)"], scale = 5)
stemgraphic.stem_graphic(data_chert["Length(mm)"], df2 = data_flint["Length(mm)"], scale = 10)
# Out:
# (<Figure size 360x180 with 2 Axes>, <AxesSubplot:>)

# %%
#연습문제3
stemgraphic.stem_graphic(data_PR["Length(mm)"], df2 = data_WF["Length(mm)"], scale = 1)
stemgraphic.stem_graphic(data_PR["Length(mm)"], df2 = data_WF["Length(mm)"], scale = 5)
stemgraphic.stem_graphic(data_PR["Length(mm)"], df2 = data_WF["Length(mm)"], scale = 10)
# Out:
# (<Figure size 360x180 with 2 Axes>, <AxesSubplot:>)
